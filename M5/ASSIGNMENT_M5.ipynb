# %% [markdown]
# #   MODULE_5: ASSIGNMENT.

# %% [markdown]
# -   -   -   -   -   -   -   -   -   -

# %% [markdown]
# #       Python OOPs Questions

# %% [markdown]
# ####    1.What is Object-Oriented Programming (OOP)?
# -   OOP stands for Object-Oriented Programming.
# -   It is a programming paradigm where concepts are represented as "objects" that have data fields (attributes) and methods (functions).
# -   OOP focuses on organizing code into reusable and modular components.
# -   The main principles of OOP are encapsulation, inheritance, polymorphism, and abstraction.
# -   -   Encapsulation refers to the bundling of data (attributes) and methods that operate on that data into a single unit (class). It helps protect the data from outside interference.
# -   -   Inheritance allows a new class (child class) to inherit the properties and behaviors of an existing class (parent class).
# -   -   Polymorphism allows different classes to be treated as instances of the same class through a common interface, enabling a method to have different behaviors.
# -   -   Abstraction hides complex implementation details, showing only the essential features of an object.
#
#
# ####    2.What is a class in OOP?
# -   A class is a blueprint or a template that defines the properties and behavior of an object.
# -   It is a collection of data fields (attributes) and methods (functions) that define the characteristics of an object.
# -   A class is essentially a design pattern or a template that defines the structure and behavior of an object.
# -   Classes are the building blocks of object-oriented programming and are used to create objects.
#     -       Example:
#     -       class Dog:
#     -           def __init__(self, name, breed):
#     -               self.name = name
#     -               self.breed = breed
#     -           def bark(self):
#     -               print(f"{self.name} says woof!")
#     -       dog1 = Dog("Buddy", "Golden Retriever")
#     -       dog1.bark()  #Output: Buddy says woof!
# ####    3.What is an object in OOP?
# -   An object is an instance of a class and has its own set of attributes (data).
# -   It is a concrete entity that has its own set of attributes (data) and methods (functions).
# -   An object is created based on the structure defined in its class.
#     -       Example:
#     -       class Dog:
#     -           def __init__(self, name, breed):
#     -               self.name = name
#     -               self.breed = breed
#     -           def bark(self):
#     -       dog1 = Dog("Buddy", "Golden Retriever")
#     -       print(dog1.name)  #Output:Buddy
# ####    4.What is the difference between abstraction and encapsulation?
# -   Abstraction is the practice of exposing only the necessary information to the outside world while hiding the implementation details.
#     -       Example: A car’s dashboard shows the speed and fuel levels, but you don't need to know how the engine works.
# -   Encapsulation is the practice of bundling data and methods that operate on that data within a single unit, called a class or object.
#     -       Example: A class Car may have methods like start_engine() and drive(), which operate on the internal state (data) of the car.
#
# ####    5.What are dunder methods in Python?
# -   Dunder methods (also called magic methods) are special methods in Python classes that are surrounded by double underscores on both sides (e.g., __init__, __str__, __repr__).
# -   They are used for operator overloading and other special operations.
#     -       Example: The __add__ method allows the use of the + operator on custom objects:
#     -       class Point:
#     -           def __init__(self, x, y):
#     -               self.x = x
#     -               self.y = y
#     -           def __add__(self, other):
#     -               return Point(self.x + other.x, self.y + other.y)
#     -       p1 = Point(1, 2)
#     -       p2 = Point(3, 4)
#     -       p3 = p1 + p2  # Calls __add__
#     -       print(p3.x, p3.y)  #Output: 4 6
#
# ####    6.Explain the concept of inheritance in OOP?
# -   Inheritance allows a new class (subclass) to inherit the properties and behaviors of an existing class (parent class).
# -   It promotes code reuse and creates a hierarchy of classes.
#     -       Example:
#     -       class Animal:
#     -           def speak(self):
#     -               print("Animal speaks")
#     -       class Dog(Animal):
#     -           def speak(self):
#     -               print("Dog barks")
#     -       dog = Dog()
#     -       dog.speak()  #Output: Dog barks
#
# ####    7.What is polymorphism in OOP?
# -   Polymorphism is the ability of an object to take on multiple forms, depending on the
# context in which it is used.
# -   It is the ability of an object to behave differently in different situations.
# -   It is the ability of an object to be treated as if it were of a different class
# -   It is the ability of an object to have multiple methods with the same name but different
# implementations.
# -   Polymorphism allows objects of different classes to be treated as objects of a common superclass.
# -   It enables a method to have different behaviors depending on the object calling it.
#     -       Example:    -
#     -       class Animal:
#     -           def speak(self):
#     -               print("Animal speaks")
#     -       class Dog(Animal):
#     -           def speak(self):
#     -               print("Dog barks")
#     -       class Cat(Animal):
#     -           def speak(self):
#     -               print("Cat meows")
#     -       animals = [Dog(), Cat()]
#     -       for animal in animals:
#     -           animal.speak()  #Output: Dog barks, Cat meows
#
# ####    8.How is encapsulation achieved in Python?
# -   Encapsulation is achieved in Python by using classes and objects.
# -   Encapsulation in Python is achieved using classes and objects, and private variables and methods.
# -   Variables and methods with double underscores (__) are considered private and are not accessible directly from outside the class.
#     -       Example:
#     -       class Person:
#     -           def __init__(self, name):
#     -               self.__name = name
#     -           def get_name(self):
#     -               return self.__name
#     -       person = Person("John")
#     -       print(person.get_name())  #Output: John
#
# ####    9.What is a constructor in Python?
# -   A constructor is a special method in Python classes that is used to initialize objects.
# -   The constructor method is called when an object is created from a class.
# -   It is used to set the initial state of an object.
# -   It is used to initialize the attributes of an object.
#
#     -       Example:
#     -       class Person:
#     -           def __init__(self, name, age):
#     -               self.name = name
#     -               self.age = age
#     -       person = Person("Alice", 30)
#
# ####    10.What are class and static methods in Python?
# -   Class methods are methods that are bound to the class rather than the instance of the class.
# -   They are used to define a method that is shared by all instances of a class.
# -   They are used to define a method that operates on the class itself, rather than on an
# instance of the class.
# -   Static methods are methods that belong to a class rather than an instance of the class.
# -   They are used to define a method that is shared by all instances of a class.
# -   They are used to define a method that operates on the class itself, rather than on an
# instance of the class.
#     -       Edit
#     -       class MyClass:
#     -           @classmethod
#     -           def class_method(cls):
#     -               print("This is a class method.")
#     -           @staticmethod
#     -           def static_method():
#     -               print("This is a static method.")
#     -       MyClass.class_method()  #Output: This is a class method.
#     -       MyClass.static_method()  #Output: This is a static method.
#
# ####    11.What is method overloading in Python?
# -   Method overloading is a feature in Python that allows multiple methods with the same name to be
# defined, but with different parameters.
# -   It is a way to provide multiple implementations of a method, depending on the number and types
# of arguments passed to it.
# -   It is a way to provide a single interface to a method, but with different implementations
# depending on the context in which it is used.
#     -       Example:
#     -       class Math:
#     -           def add(self, a, b=0):
#     -               return a + b
#     -       math = Math()
#     -       print(math.add(5))  #Output: 5
#     -       print(math.add(5, 3))  #Output: 8
#
# ####    12.What is method overriding in OOP?
# -   Method overriding is a feature in OOP that allows a subclass to provide a different implementation of
# a method that is already defined in its superclass.
# -   It is a way to provide a new implementation of a method that is already defined in a
# superclass.
# -   It is a way to provide a different behavior for a method that is already defined in a
# superclass.
#     -       Example:
#     -       class Animal:
#     -           def sound(self):
#     -               print("Animal sound")
#     -       class Dog(Animal):
#     -           def sound(self):
#     -               print("Bark")
#     -       dog = Dog()
#     -       dog.sound()  #Output: Bark
#
# ####    13.What is a property decorator in Python?
# -   A property decorator in Python is used to define methods that get, set, or delete an attribute of a class while maintaining an object's encapsulation.
# -   It allows a method to be accessed like an attribute while adding additional functionality to getting, setting, or deleting the attribute.
# -   The @property decorator is used to create a getter method, @<property_name>.setter for the setter, and @<property_name>.deleter for deleting the property.
#     -       Example:
#     -       class Circle:
#     -           def __init__(self, radius):
#     -               self._radius = radius
#     -
#     -           @property
#     -           def radius(self):
#     -               return self._radius
#     -
#     -           @radius.setter
#     -           def radius(self, value):
#     -               if value < 0:
#     -                   raise ValueError("Radius cannot be negative.")
#     -               self._radius = value
#     -
#     -           @radius.deleter
#     -           def radius(self):
#     -               print("Deleting radius...")
#     -               del self._radius
#
#     -       # Example usage:
#     -       circle = Circle(5)
#     -       print(circle.radius)  #Calls the getter
#     -       circle.radius = 10    #Calls the setter
#     -       del circle.radius     #Calls the delete
#
# ####    14.Why is polymorphism important in OOP?
# -   Polymorphism allows different classes to be treated as objects of a common superclass, promoting flexibility in code.
# -   It enables methods to be written that can work with objects of different classes, reducing complexity and making the code more scalable.
# With polymorphism, the same method or function can have different behaviors based on the object calling it.
#     -       Example:
#     -       class Animal:
#     -           def make_sound(self):
#     -               print("Some generic animal sound")
#     -
#     -       class Dog(Animal):
#     -           def make_sound(self):
#     -               print("Woof!")
#     -
#     -       class Cat(Animal):
#     -           def make_sound(self):
#     -               print("Meow!")
#
#     -       def make_animal_sound(animal: Animal):
#     -           animal.make_sound()
#
#     -       # Polymorphism in action
#     -       dog = Dog()
#     -       cat = Cat()
#
#     -       make_animal_sound(dog)  #Outputs: Woof!
#     -       make_animal_sound(cat)  #Outputs: Meow!
#
# ####    15.What is an abstract class in Python?
# -   An abstract class in Python is a class that cannot be instantiated on its own and is
# designed to be subclassed by other classes.
# -   It is a class that provides a blueprint for other classes to follow.
# -   It is a class that defines a common interface for a group of related classes.
#     -       Example:
#     -       from abc import ABC, abstractmethod
#
#     -       class Animal(ABC):
#     -           @abstractmethod
#     -           def make_sound(self):
#     -               pass
#
#     -       class Dog(Animal):
#     -           def make_sound(self):
#     -               print("Woof!")
#
#     -       # animal = Animal()  # This will raise an error because Animal is abstract
#     -       dog = Dog()
#     -       dog.make_sound()  #Outputs: Woof!
#
# ####    16.What are the advantages of OOP?
# -   Encapsulation: OOP provides a way to encapsulate data and behavior into a single unit
# -   Inheritance: OOP provides a way to inherit behavior from a superclass
# -   Polymorphism: OOP provides a way to write methods that can operate on objects of
# different classes
# -   Abstraction: OOP provides a way to abstract away implementation details and focus on
# interface
# -   Reusability: OOP provides a way to write code that can be reused in different
# contexts.
#
# ####    17.What is the difference between a class variable and an instance variable?
# -   A class variable is a variable that is shared by all instances of a class.
# -   An instance variable is a variable that is unique to each instance of a class.
# -   A class variable is defined inside a class definition, while an instance variable is defined inside a
# method definition.
#     -       Example:
#     -       class Car:
#     -           wheels = 4  # Class variable
#
#     -           def __init__(self, color):
#     -               self.color = color  # Instance variable
#
#     -       car1 = Car("Red")
#     -       car2 = Car("Blue")
#
#     -       print(car1.wheels)  #4
#     -       print(car2.color)  #Blue
#
# ####    18.What is multiple inheritance in Python?
# -   Multiple inheritance in Python is a feature that allows a class to inherit behavior from multiple
# superclasses.
# -   It is a way to inherit behavior from multiple classes.
# -   It is a way to create a class that has multiple parents.
# -   Multiple inheritance occurs when a class is derived from more than one base class. This allows a class to inherit behaviors from multiple classes.
# -   It can be useful, but Python's method resolution order (MRO) ensures that ambiguity is resolved.
#     -       Example:
#     -       class Animal:
#     -           def eat(self):
#     -               print("Eating")
#
#     -       class Mammal:
#     -           def nurse(self):
#     -               print("Nursing")
#
#     -       class Bat(Animal, Mammal):
#     -           def fly(self):
#     -               print("Flying")
#
#     -       bat = Bat()
#     -       bat.eat()   #Inherited from Animal
#     -       bat.nurse() #Inherited from Mammal
#     -       bat.fly()   #Defined in Bat
#
# ####    19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# -   The purpose of the ‘__str__’ method in Python is to return a string representation
# of an object that is suitable for end-users.
# -   The purpose of the ‘__repr__’ method in Python is to return a string representation
# of an object that is suitable for developers.
# -   The ‘__str__’ method is used to provide a human-readable representation of an object
# -   The ‘__repr__’ method is used to provide a developer-readable representation of an object
# -   The ‘__str__’ method is used to provide a string that can be used in
# print() function
# -   The ‘__repr__’ method is used to provide a string that can be used in
# repr() function
#     -       Example:
#     -       class Car:
#     -           def __init__(self, make, model):
#     -               self.make = make
#     -               self.model = model
#
#     -           def __str__(self):
#     -               return f"A car: {self.make} {self.model}"
#
#     -           def __repr__(self):
#     -               return f"Car(make='{self.make}', model='{self.model}')"
#
#     -       car = Car("Toyota", "Camry")
#     -       print(str(car))   #A car: Toyota Camry
#     -       print(repr(car))  #Car(make='Toyota', model='Camry')
#
# ####    20.What is the significance of the ‘super()’ function in Python?
# -   The ‘super()’ function in Python is used to access the methods of a parent class
# -   It is used to call the methods of a parent class from a child class
# -   It is used to access the attributes of a parent class from a child class
# -   It is used to create a new instance of a parent class from a child class
# -   It is used to access the methods of a parent class from a child class in a multiple
# inheritance scenario.
#     -       Example:
#     -       class Animal:
#     -           def speak(self):
#     -               print("Animal makes a sound")
#
#     -       class Dog(Animal):
#     -           def speak(self):
#     -               super().speak()  # Calls the speak method from Animal class
#     -               print("Woof!")
#
#     -       dog = Dog()
#     -       dog.speak()
#     -       #Output:
#     -       #Animal makes a sound
#     -       #Woof!
#
# ####    21.What is the significance of the __del__ method in Python?
# -   The __del__ method in Python is a special method that is called when an object is
# about to be destroyed
# -   It is used to perform any necessary cleanup or finalization before an object is
# destroyed
# -   It is used to release any system resources that an object is using
# -   It is used to perform any necessary actions when an object is about to be
# destroyed
# -   It is used to perform any necessary actions when an object is about to be
# deleted.
#     -       Example:
#     -       class FileHandler:
#     -           def __init__(self, filename):
#     -               self.filename = filename
#     -               self.file = open(filename, 'w')
#
#     -           def write_data(self, data):
#     -               self.file.write(data)
#
#     -           def __del__(self):
#     -               print(f"Closing file {self.filename}")
#     -               self.file.close()
#
#     -       # When the object is deleted, __del__ is called
#     -       file_handler = FileHandler("data.txt")
#     -       file_handler.write_data("Some data")
#     -       del file_handler  #This will call __del__
#
# ####    22.What is the difference between @staticmethod and @classmethod in Python?
# -   The @staticmethod decorator in Python is used to define a static method, which is a method
# that belongs to a class rather than an instance of the class.
# -   The @classmethod decorator in Python is used to define a class method, which is a method
# that belongs to a class and takes the class as an implicit first argument.
# -   A static method does not take any implicit arguments, while a class method takes the class as
# an implicit first argument.
# -   A static method is used to define a method that does not depend on the state of the
# class, while a class method is used to define a method that depends on the state of the class
# -   A static method is used to define a method that can be called without creating an instance of
# the class, while a class method is used to define a method that can be called without creating an
# instance of the class.
#     -       Example:
#     -       class MyClass:
#     -           class_var = "I am a class variable"
#
#     -           @staticmethod
#     -           def static_method():
#     -               print("This is a static method.")
#
#     -           @classmethod
#     -           def class_method(cls):
#     -               print(f"This is a class method. Class variable: {cls.class_var}")
#
#     -       MyClass.static_method()  #No need for class or instance reference
#     -       MyClass.class_method()   #Needs class reference
#
# ####    23.How does polymorphism work in Python with inheritance?
# -   Polymorphism in Python with inheritance works by allowing a child class to inherit the
# attributes and methods of a parent class and then override them with its own implementation.
# -   This allows a child class to provide a different implementation of a method than its parent class.
# -   The child class can also add new methods or attributes that are not present in the parent class When a method is called on an instance of a child class, Python will first look for the method in the child class. If it is not found, it will then look for it in
# the parent class and so on up the inheritance chain.
#     -       Example:
#     -       class Shape:
#     -           def area(self):
#     -               raise NotImplementedError("Subclasses must implement this method")
#
#     -       class Rectangle(Shape):
#     -           def __init__(self, width, height):
#     -               self.width = width
#     -               self.height = height
#
#     -           def area(self):
#     -               return self.width * self.height
#
#     -       class Circle(Shape):
#     -           def __init__(self, radius):
#     -               self.radius = radius
#
#     -           def area(self):
#     -               return 3.14 * (self.radius ** 2)
#
#     -       shapes = [Rectangle(10, 5), Circle(3)]
#     -       for shape in shapes:
#     -           print(f"Area: {shape.area()}")
#
#
# ####    24.What is method chaining in Python OOP?
# -   Method chaining in Python OOP is a technique where a method returns the object itself
# -   This allows multiple method calls to be chained together in a single line of code
# -   It is used to make the code more readable and easier to use
# -   It is used to reduce the number of lines of code
# -   It is used to improve the performance of the code
# -   It is used to make the code more object-oriented
# -   It is used to make the code more functional
# -   It is used to make the code more modular
# -   It is used to make the code more reusable
# -   It is used to make the code more maintainable
# -   It is used to make the code more scalable
#     -       Example:
#     -       class Car:
#     -           def __init__(self, make):
#     -               self.make = make
#
#     -           def set_make(self, make):
#     -               self.make = make
#     -               return self  # Returning the object itself to allow chaining
#
#     -           def display(self):
#     -               print(f"Car make: {self.make}")
#     -               return self
#
#     -       car = Car("Toyota")
#     -       car.set_make("Honda").display()
#
# ####    25.What is the purpose of the __call__ method in Python?
# -   The __call__ method in Python is a special method that allows an object to be called
# like a function
# -   It is used to make an object callable
# -   It is used to make an object behave like a function
# -   It is used to make an object behave like a method
# -   It is used to make an object behave like a class
# -   It is used to make an object behave like a module
#     -       Example:
#     -       class Adder:
#     -           def __init__(self, increment):
#     -               self.increment = increment
#
#     -           def __call__(self, number):
#     -               return number + self.increment
#
#     -       add_five = Adder(5)
#     -       print(add_five(10))  #Outputs: 15

# %% [markdown]
# -   -   -   -   -   -   -   -   -   -

# %% [markdown]
# #   Practical Questions

# %%
'''   1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".    '''

class Animal:
    def speak(self):
        print("The animal makes a sound.")
class Dog(Animal):
    def speak(self):
        print("Bark!")
        # Create an instance of Dog
dog = Dog() 
dog.speak()
# Out:
# Bark!

# %%
''' 2.Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.  '''
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def areaa(self):
        pass

# Derived class Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def areaa(self):
        return math.pi * self.radius ** 2

# Derived class Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def areaa(self):
        return self.length * self.width

# Create instances
circle = Circle(5)
rectangle = Rectangle(4, 6)

# Print areas
print(f"Area of Circle: {circle.areaa():.2f}")
print(f"Area of Rectangle: {rectangle.areaa()}")
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %%
''' 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute. '''
class Vehicle:
    def __init__(self, type):
        self.type = type
class Car(Vehicle):
    def __init__(self, type, num_doors,model):
        super().__init__(type)
        self.model = model
        self.num_doors = num_doors
    def view(self):
        print(f"Model: {self.model}, Number of Doors: {self.num_doors}")
class ElectricCar(Car):
    def __init__(self, type, num_doors,model, battery_capacity):
        super().__init__(type, num_doors,model)
        self.battery_capacity = battery_capacity
    def view(self):
        super().view()
        print(f"Battery Capacity: {self.battery_capacity}")
    # Test the classes
car=Car("Petrol",5,"Safari")
car.view()
my_car = ElectricCar("Electric", 4, "Tesla", 100)
my_car.view()
# Out:
# Model: Safari, Number of Doors: 5
# Model: Tesla, Number of Doors: 4
# Battery Capacity: 100

# %%
''' 4.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute. '''
class Vehicle:
    def __init__(self, type):
        self.type = type
class Car(Vehicle):
    def __init__(self, type, num_doors,model):
        super().__init__(type)
        self.model = model
        self.num_doors = num_doors
    def view(self):
        print(f"Model: {self.model}, Number of Doors: {self.num_doors}")
class ElectricCar(Car):
    def __init__(self, type, num_doors,model, battery_capacity):
        super().__init__(type, num_doors,model)
        self.battery_capacity = battery_capacity
    def view(self):
        super().view()
        print(f"Battery Capacity: {self.battery_capacity}")
    # Test the classes
car=Car("Petrol",5,"Safari")
car.view()
my_car = ElectricCar("Electric", 4, "Tesla", 100)
my_car.view()
# Out:
# Model: Safari, Number of Doors: 5
# Model: Tesla, Number of Doors: 4
# Battery Capacity: 100

# %%
''' 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance. '''
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance
        return print (f"AC Balance:{self.__balance}")
    def deposit(self, amount):
            self.__balance += amount
            return print(f"The Amount deposti is :${amount} and tola AC Balance is : {self.__balance}")
    def withdraw(self, amount):
            if amount > self.__balance:
                print(f"Insufficient balance:{amount}")
            else:
                print("\nAmount Withdrawall")
                self.__balance -= amount
                return  print(f"The Amount Withdrawall is :${amount} and Remaning AC Balance is : {self.__balance}")
    def check_balance(self):
                return self.__balance
# Create an instance of BankAccount
account = BankAccount(1000)
# Deposit $500
account.deposit(500)
# Withdraw $200
account.withdraw(200)
# Check balance
print("Balance:", account.check_balance())
# Out:
# AC Balance:1000
# The Amount deposti is :$500 and tola AC Balance is : 1500
#
# Amount Withdrawall
# The Amount Withdrawall is :$200 and Remaning AC Balance is : 1300
# Balance: 1300

# %%
''' 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().  '''
class Instrument:
    def play(self):
        print("Playing an instrument")
class Guitar(Instrument):
    def play(self):
        print("Playing a guitar")
class Piano(Instrument):
    def play(self):
        print("Playing a piano")
# Create instances of Guitar ,Piano ,Instrument
guitar = Guitar()
piano = Piano()
instrument= Instrument()
# Call the play() method on each instance
guitar.play()
piano.play()
instrument.play()
# Out:
# Playing a guitar
# Playing a piano
# Playing an instrument

# %%
''' 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers.   '''
class MathOperations:
    @classmethod
    def add_numbers(cls, num1, num2):
        return num1 + num2
    @staticmethod
    def subtract_numbers(num1, num2):
        return num1 - num2

print(MathOperations.add_numbers(10, 5)) 
print(MathOperations.subtract_numbers(10, 5))
# Out:
# 15
# 5

# %%
''' 8. Implement a class Person with a class method to count the total number of persons created. '''
class Person:
    _total_persons = 0
    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person._total_persons += 1
    @classmethod
    def get_total_persons(cls):
        return cls._total_persons
        
p1=Person("ram",20)
p2=Person("Sham",24)
p3=Person("Sham",24)
p4=Person("Sham",24)
print(Person.get_total_persons())
# Out:
# 4

# %%
''' 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator". '''
import math
class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero")
        gcd = math.gcd(numerator, denominator)  # Find GCD to simplify
        self.numerator = numerator // gcd
        self.denominator = denominator // gcd

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Test the class
fraction = Fraction(5, 2)
print(fraction)  
fraction2 = Fraction(4, 2)
print(fraction2)
# Out:
# 5/2
# 2/1

# %%
''' 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors. '''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if not isinstance(other, Vector):
            return NotImplemented  
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Test the class
v1 = Vector(3, 4)
v2 = Vector(1, 2)
v3 = v1 + v2  

print(v3)
# Out:
# (4, 6)

# %%
''' 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old." '''
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p1=Person("Ram",24)
p1.greet()
# Out:
# Hello, my name is Ram and I am 24 years old.

# %%
''' 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades. '''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of grades

    def average_grade(self):
        if not self.grades:
            return 0  # Return 0 if no grades available to avoid division by zero
        return sum(self.grades) / len(self.grades)

    def __str__(self):
        return f"Student: {self.name}, Average Grade: {self.average_grade():.2f}"

# Test the class
student1 = Student("Sanvi", [85, 90, 78, 92])
student2 = Student("Mallika", [70, 88, 94])

print(student1) 
print(student2)
# Out:
# Student: Sanvi, Average Grade: 86.25
# Student: Mallika, Average Grade: 84.00

# %%
''' 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area. '''
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width
        return self.length, self.width
    def area(self):
        return self.length * self.width
R1=Rectangle()
print(R1.set_dimensions(10,15))
# Out:
# (10, 15)

# %%
''' 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary '''
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus
    
    def __str__(self):
        return f"Manager: {self.name}, Salary: {self.calculate_salary():.2f} (Includes Bonus)"

# Creating Employee and Manager objects
Emp1 = Employee("Sham", 500, 350)
print(Emp1.calculate_salary())  

Manager1 = Manager("Sham", 500, 350, 1000)
print(Manager1)
# Out:
# 175000
# Manager: Sham, Salary: 176000.00 (Includes Bonus)

# %%
''' 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product. '''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def total_price(self):
        return print(f"the total price of cart is :{self.price * self.quantity}")
# create an object of Product class
product = Product("apple", 10, 5)
product.total_price()
# Out:
# the total price of cart is :50

# %%
''' 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method.   '''
class Animal:
    def sound(self):
        pass
class Cow(Animal):
    def sound(self):
        return "Moo"
class Sheep(Animal):
    def sound(self):
        return "Baa"
# Creating an objests 
cow = Cow()
sheep = Sheep()
print(cow.sound())  
print(sheep.sound())
# Out:
# Moo
# Baa

# %%
''' 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.  '''
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Test the class
book = Book("To Kill a Mockingbird", "Harper Lee", 1960)
print(book.get_book_info())
# Out:
# Title: To Kill a Mockingbird
# Author: Harper Lee
# Year Published: 1960

# %%
''' 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms.    '''
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_house_info(self):
        return f"Address: {self.address}\nPrice: {self.price}"

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_mansion_info(self):
        house_info = self.get_house_info()  # Get the basic house info
        return f"{house_info}\nNumber of Rooms: {self.number_of_rooms}"

# Test the classes
house1 = House("123 Elm St.", 200000)
mansion1 = Mansion("456 Oak Ave.", 5000000, 20)

# Display information
print(house1.get_house_info())
print("---")
print(mansion1.get_mansion_info())
# Out:
# Address: 123 Elm St.
# Price: 200000
# ---
# Address: 456 Oak Ave.
# Price: 5000000
# Number of Rooms: 20

# %% [markdown]
# -   -   -   -   -   -   -   -   -   -
